# %%
# !pip install jsonlines

# %%
from pydantic import BaseModel, Field
from enum import Enum
from typing import Optional, List
from openai import OpenAI
from typing import Dict
from tqdm import tqdm
import json
import jsonlines
import os
import re
import pandas as pd

from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

# %%
client = OpenAI(
    base_url="http://localhost:8001/v1",
    api_key="-",
)
model = client.models.list().data[0].id
model
# Out:
# '/models/Qwen3-0.6B-Base'

# %%
class BugStatus(str, Enum):
    BUG = "True"
    NO_BUG = "False"

class ClassificationResult(BaseModel):
    has_bug: BugStatus
    bugs_free_version: str = Field(default=None, description="Optional fix attempt if model detects a bug - Use it only in case of a bug! else, set null")

json_schema = ClassificationResult.model_json_schema()

# %%
def benchmark_openai_structured_model(
    test_data: List[Dict],
    client,
    json_schema: dict,
    output_path: str = None,
    temperature: float = 0.0,
    max_tokens: int = 2056,
    save_every: int = 25,
    start_index: int = 0,
):
    benchmark_results = []

    # Check if output file exists and resume from there
    if output_path and os.path.exists(output_path):
        with open(output_path, "r") as f:
            benchmark_results = json.load(f)
        start_index = len(benchmark_results)
        print(f"Resuming from index {start_index}, loaded {len(benchmark_results)} existing results.")

    for i in tqdm(range(start_index, len(test_data)), desc=f"Benchmarking {model}"):
        entry = test_data[i]
        messages = [m for m in entry["messages"] if m["role"] != "assistant"]

        try:
            completion = client.chat.completions.create(
                model=model,
                temperature=temperature,
                max_tokens=max_tokens,
                messages=[
                    entry["messages"][0], # System message
                    entry["messages"][1], # User message
                ],
                # response_format={
                #     "type": "json_schema",
                #     "json_schema": {
                #         "name": "code-diagnostic",
                #         "schema": json_schema
                #     },
                # },
            )

            output_content = completion.choices[0].message.content
            # cleaned_output = re.sub(r"<think>.*?</think>", "", output_content, flags=re.DOTALL)

            benchmark_results.append({
                "index": i,
                "input": messages,
                "output": output_content
            })

        except Exception as e:
            benchmark_results.append({
                "index": i,
                "input": messages,
                "error": str(e)
            })

        # Save progress every `save_every` entries
        if output_path and (i + 1) % save_every == 0:
            with open(output_path, "w") as f:
                json.dump(benchmark_results, f, indent=2)
            

    # Final save
    if output_path:
        with open(output_path, "w") as f:
            json.dump(benchmark_results, f, indent=2)
        print("Final results saved.")

    return benchmark_results

# %%
# FIXME - a tmp remove
# os.remove("/home/odedh/SML-For-Debug/benchmark/benchmark_results_Qwen3-0.6B_no_finetunes.json")

with jsonlines.open("/home/odedh/SML-For-Debug/data/dataset/pyresbugs_test.jsonl") as reader:
    test_set = list(reader)

results = benchmark_openai_structured_model(
    test_data=test_set,
    client=client,
    json_schema=json_schema,
    output_path="benchmark_results_Qwen3-0.6B_no_finetunes.json",
    save_every=10,
)
# Out:
# Benchmarking /models/Qwen3-0.6B-Base:   2%|▏         | 19/1002 [01:34<1:21:25,  4.97s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 7
#       4 with jsonlines.open("/home/odedh/SML-For-Debug/data/dataset/pyresbugs_test.jsonl") as reader:
#       5     test_set = list(reader)
# ----> 7 results = benchmark_openai_structured_model(
#       8     test_data=test_set,
#       9     client=client,
#      10     json_schema=json_schema,
#      11     output_path="benchmark_results_Qwen3-0.6B-Base_no_finetunes.json",
#      12     save_every=10,
#      13 )
#
# Cell In[5], line 25, in benchmark_openai_structured_model(test_data, client, json_schema, output_path, temperature, max_tokens, save_every, start_index)
#      22 messages = [m for m in entry["messages"] if m["role"] != "assistant"]
#      24 try:
# ---> 25     completion = client.chat.completions.create(
#      26         model=model,
#      27         temperature=temperature,
#      28         max_tokens=max_tokens,
#      29         messages=[
#      30             entry["messages"][0], # System message
#      31             entry["messages"][1], # User message
#      32         ],
#      33         # response_format={
#      34         #     "type": "json_schema",
#      35         #     "json_schema": {
#      36         #         "name": "code-diagnostic",
#      37         #         "schema": json_schema
#      38         #     },
#      39         # },
#      40     )
#      42     output_content = completion.choices[0].message.content
#      43     # cleaned_output = re.sub(r"<think>.*?</think>", "", output_content, flags=re.DOTALL)
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/openai/_utils/_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:1087, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1044 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1045 def create(
#    1046     self,
#    (...)
#    1084     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1085 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1086     validate_response_format(response_format)
# -> 1087     return self._post(
#    1088         "/chat/completions",
#    1089         body=maybe_transform(
#    1090             {
#    1091                 "messages": messages,
#    1092                 "model": model,
#    1093                 "audio": audio,
#    1094                 "frequency_penalty": frequency_penalty,
#    1095                 "function_call": function_call,
#    1096                 "functions": functions,
#    1097                 "logit_bias": logit_bias,
#    1098                 "logprobs": logprobs,
#    1099                 "max_completion_tokens": max_completion_tokens,
#    1100                 "max_tokens": max_tokens,
#    1101                 "metadata": metadata,
#    1102                 "modalities": modalities,
#    1103                 "n": n,
#    1104                 "parallel_tool_calls": parallel_tool_calls,
#    1105                 "prediction": prediction,
#    1106                 "presence_penalty": presence_penalty,
#    1107                 "reasoning_effort": reasoning_effort,
#    1108                 "response_format": response_format,
#    1109                 "seed": seed,
#    1110                 "service_tier": service_tier,
#    1111                 "stop": stop,
#    1112                 "store": store,
#    1113                 "stream": stream,
#    1114                 "stream_options": stream_options,
#    1115                 "temperature": temperature,
#    1116                 "tool_choice": tool_choice,
#    1117                 "tools": tools,
#    1118                 "top_logprobs": top_logprobs,
#    1119                 "top_p": top_p,
#    1120                 "user": user,
#    1121                 "web_search_options": web_search_options,
#    1122             },
#    1123             completion_create_params.CompletionCreateParamsStreaming
#    1124             if stream
#    1125             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1126         ),
#    1127         options=make_request_options(
#    1128             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1129         ),
#    1130         cast_to=ChatCompletion,
#    1131         stream=stream or False,
#    1132         stream_cls=Stream[ChatCompletionChunk],
#    1133     )
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/openai/_base_client.py:1256, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1242 def post(
#    1243     self,
#    1244     path: str,
#    (...)
#    1251     stream_cls: type[_StreamT] | None = None,
#    1252 ) -> ResponseT | _StreamT:
#    1253     opts = FinalRequestOptions.construct(
#    1254         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1255     )
# -> 1256     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/openai/_base_client.py:979, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     977 response = None
#     978 try:
# --> 979     response = self._client.send(
#     980         request,
#     981         stream=stream or self._should_stream_response_body(request=request),
#     982         **kwargs,
#     983     )
#     984 except httpx.TimeoutException as err:
#     985     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Creating the benchmark DF

# %%
benchmark_path = "/home/odedh/SML-For-Debug/benchmark/benchmark_results_Qwen3-0.6B_no_finetunes.json"
dataset_path = "/home/odedh/SML-For-Debug/data/dataset/pyresbugs_test.jsonl"

# %%
def robust_json_parse(text):
    """
    Attempts to extract and parse a JSON object from a string that may contain
    extra markdown, prefix/suffix, or formatting artifacts.
    """
    if not isinstance(text, str):
        return None

    # Remove Markdown-style code blocks
    cleaned = re.sub(r"```json|```", "", text.strip(), flags=re.IGNORECASE)
    
    # Extract the thinking part if it exists
    thinking_part = re.search(r"<think>(.*?)</think>", cleaned, flags=re.DOTALL)
    if thinking_part:
        cleaned = re.sub(r"<think>.*?</think>", "", cleaned, flags=re.DOTALL)
        thinking_part = thinking_part.group(1).strip()

    # Find the first JSON-like object using regex (handles nested braces)
    match = re.search(r"\{.*\}", cleaned, flags=re.DOTALL)
    if match:
        json_str = match.group(0)
        try:
            json_obj = json.loads(json_str)
            json_obj['thinking'] = thinking_part if thinking_part else None
            return json_obj
        except json.JSONDecodeError:
            # Try to fix common issues like escaped quotes
            try:
                fixed_json_str = json_str.replace("\\'", "'").replace('\\"', '"')
                json_obj = json.loads(fixed_json_str)
                json_obj['thinking'] = thinking_part if thinking_part else None
                return json_obj
            except Exception:
                return None
    return None

# %%
with open(benchmark_path, "r") as f:
    benchmark_data = json.load(f)

# Load JSONL dataset
dataset = []
with open(dataset_path, "r") as f:
    for line in f:
        dataset.append(json.loads(line))

# Build dataframe
records = []

for entry_gt, entry_model in zip(dataset, benchmark_data):
    # Extract ground truth
    user_msg = next(m for m in entry_gt["messages"] if m["role"] == "user")
    assistant_msg = next(m for m in entry_gt["messages"] if m["role"] == "assistant")
    source_code = str(user_msg["content"])
    prompt = entry_gt["messages"][0]["content"]

    try:
        gt_response = json.loads(assistant_msg["content"])
        gt_is_buggy = 'true' == gt_response['has_bug'].lower()
        gt_fix = gt_response.get("Code", None)
        gt_acronym = gt_response.get("Fault_Acronym", None)
    except Exception:
        gt_is_buggy = None
        gt_fix = None
        gt_acronym = None

    # Extract model output
    try:
        model_output = robust_json_parse(entry_model["output"])
        model_is_buggy = model_output.get("has_bug", "").lower() == "true"
        model_fix = model_output.get("bugs_free_version", None)
        model_thinking = model_output.get("thinking", None)
    except Exception as e:
        model_is_buggy = None
        model_fix = None
        model_thinking = None

    records.append({
        "input_prompt": prompt.strip(),
        "source_code": source_code.strip(),
        "ground_truth_is_buggy": gt_is_buggy,
        "ground_truth_fix": gt_fix,
        "ground_truth_acronym": gt_acronym,
        "model_is_buggy": model_is_buggy,
        "model_suggested_fix": model_fix,
        "model_thinking": model_thinking,
    })

df = pd.DataFrame(records)
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with open(benchmark_path, "r") as f:
#       2     benchmark_data = json.load(f)
#       4 # Load JSONL dataset
#
# Cell In[1], line 1
# ----> 1 with open(benchmark_path, "r") as f:
#       2     benchmark_data = json.load(f)
#       4 # Load JSONL dataset
#
# File _pydevd_bundle\\pydevd_cython.pyx:1697, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython.pyx:634, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1112, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1090, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:494, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:2188, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2185             from_this_thread.append(frame_custom_thread_id)
#    2187     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2188         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2190 frames_list = None
#    2192 if keep_suspended:
#    2193     # This means that we should pause again after a set next statement.
#
# File ~/SML-For-Debug/.venv/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:2257, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2254                 queue.put(internal_cmd)
#    2255                 wait_timeout = TIMEOUT_FAST
# -> 2257         notify_event.wait(wait_timeout)
#    2258         notify_event.clear()
#    2260 finally:
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ### EDA

# %%
# Filter rows where model prediction exists and ground truth is defined
valid_df = df[df["model_is_buggy"].notnull() & df["ground_truth_is_buggy"].notnull()]

# Ensure both are booleans
y_true = valid_df["ground_truth_is_buggy"].astype(bool)
y_pred = valid_df["model_is_buggy"].astype(bool)

# Basic classification metrics
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
conf_matrix = confusion_matrix(y_true, y_pred)

# Per-class F1 score by acronym
f1_per_acronym = {}
acronym_df = valid_df[valid_df["ground_truth_is_buggy"] == True]
for acronym in acronym_df["ground_truth_acronym"].dropna().unique():
    sub_df = acronym_df[acronym_df["ground_truth_acronym"] == acronym]
    if not sub_df.empty:
        y_true_acr = sub_df["ground_truth_is_buggy"].astype(bool)
        y_pred_acr = sub_df["model_is_buggy"].astype(bool)
        score = f1_score(y_true_acr, y_pred_acr, zero_division=0)
        f1_per_acronym[acronym] = score

# Convert to DataFrame for display
f1_acronym_df = pd.DataFrame(list(f1_per_acronym.items()), columns=["Fault_Acronym", "F1_Score"]).sort_values(by="F1_Score", ascending=False)

# Return all to user
{
    "precision": precision,
    "recall": recall,
    "f1_score": f1,
    "confusion_matrix": conf_matrix.tolist(),
    "total_samples": len(valid_df)
}
# Out:
# {'precision': 0.5333333333333333,
#  'recall': 0.24060150375939848,
#  'f1_score': 0.3316062176165803,
#  'confusion_matrix': [[336, 84], [303, 96]],
#  'total_samples': 819}

# %% [markdown]
# ## 🧪 Model Performance Summary (Bug Classification)
#
# The model was evaluated on 819 samples from a structured bug detection benchmark. It was tasked with classifying whether a given code snippet is buggy or bug-free. Below is a summary of its performance:
#
# ### 📈 Classification Metrics
#
# - **Precision**: `53.3%`
#   The model correctly identified bugs in 53.3% of the cases it predicted as buggy.
#
# - **Recall**: `24.1%`
#   The model only caught 24.1% of all actual buggy code samples, indicating a high miss rate.
#
# - **F1 Score**: `33.2%`
#   A low F1 score reflects a poor balance between precision and recall, with many false negatives.
#
# - **Total Evaluated Samples**: `819`
#
# ---
#
# ### 🔍 Confusion Matrix
#
# |                       | Predicted: Bug-Free | Predicted: Buggy |
# |-----------------------|---------------------|------------------|
# | **Actual: Bug-Free**  | 336 (True Negatives) | 84 (False Positives) |
# | **Actual: Buggy**     | 303 (False Negatives) | 96 (True Positives) |
#
# ---
#
# ### 📊 Key Observations
#
# - The model **performs better at identifying clean code** than detecting buggy code.
# - It **misses the majority of actual bugs**, with 303 false negatives.
# - While **precision is moderate**, recall is notably low — indicating that the model is overly conservative.
# - This behavior suggests that relying solely on this model for bug detection may result in many bugs going undetected.
